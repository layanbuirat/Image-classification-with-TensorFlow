# %% [markdown]
# # Your First AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) from Oxford of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load the image dataset and create a pipeline.
# * Build and Train an image classifier on this dataset.
# * Use your trained model to perform inference on flower images.
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.

# %% [markdown]
# ## Import Resources

# %%
# TODO: Make all necessary imports.

import time
from tensorflow.keras.utils import custom_object_scope
import numpy as np
import matplotlib.pyplot as plt
import json
from PIL import Image
import tensorflow as tf
import tensorflow_hub as hub
import tensorflow_datasets as tfds
import os
from PIL import Image

tfds.disable_progress_bar()
# Out:
# 2026-05-03 17:45:11.513464: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777830311.539590     463 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777830311.547477     463 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1777830311.567518     463 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777830311.567538     463 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777830311.567540     463 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777830311.567543     463 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %% [markdown]
# ## Load the Dataset
#
# Here you'll use `tensorflow_datasets` to load the [Oxford Flowers 102 dataset](https://www.tensorflow.org/datasets/catalog/oxford_flowers102). This dataset has 3 splits: `'train'`, `'test'`, and `'validation'`.  You'll also need to make sure the training data is normalized and resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet, but you'll still need to normalize and resize the images to the appropriate size.

# %%
# TODO: Load the dataset with TensorFlow Datasets.

Dataset_of_Flowers, Dataset_of_Flowers_info = tfds.load('oxford_flowers102', with_info=True, as_supervised=True, split=['train', 'validation', 'test'])

# TODO: Create a training set, a validation set and a test set.

training_set, validation_set, test_set = Dataset_of_Flowers
# Out:
# I0000 00:00:1777830319.279407     463 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %% [markdown]
# ## Explore the Dataset

# %%
# TODO: Get the number of examples in each set from the dataset info.

num_training_samples = Dataset_of_Flowers_info.splits['train'].num_examples
num_validation_samples = Dataset_of_Flowers_info.splits['validation'].num_examples
num_test_samples = Dataset_of_Flowers_info.splits['test'].num_examples

print("Number of training samples: {}".format(num_training_samples))
print("Number of validation samples: {}".format(num_validation_samples))  
print("Number of test samples: {}".format(num_test_samples))

# TODO: Get the number of classes in the dataset from the dataset info.

total_classes = Dataset_of_Flowers_info.features['label'].num_classes
print("Number of classes: {}".format(total_classes))
# Out:
# Number of training samples: 1020
# Number of validation samples: 1020
# Number of test samples: 6149
# Number of classes: 102

# %%
# TODO: Print the shape and corresponding label of 3 images in the training set.

for image, label in training_set.take(3):
    print(f'\u2022 Image shape: {image.shape}')
    print(f'\u2022 Image label: {label}', '\n')
# Out:
# • Image shape: (500, 667, 3)
# • Image label: 72
#
# • Image shape: (500, 666, 3)
# • Image label: 84
#
# • Image shape: (670, 500, 3)
# • Image label: 70

# %%
# TODO: Plot 1 image from the training set. Set the title 

for image, label in training_set.take(1):
    image = image.numpy()  
    label = label.numpy() 
    plt.imshow(image)
    plt.title(f"Label: {label}")
    plt.show()

# %% [markdown]
# ### Label Mapping
#
# You'll also need to load in a mapping from label to category name. You can find this in the file `label_map.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/3.7/library/json.html). This will give you a dictionary mapping the integer coded labels to the actual names of the flowers.

# %%
with open('/kaggle/input/datasets/leyanbuirat/lab-map/label_map.json', 'r') as f:
    class_names = json.load(f)

# %%
#TODO: Plot 1 image from the training set. Set the title

for image, label in training_set.take(1):
    image = image.numpy()
    label = label.numpy()
    label_str = str(label)  
    class_name = class_names[label_str]
    plt.imshow(image)
    plt.title(f"Class: {class_name}")
    plt.axis('off')
    plt.show()

# %% [markdown]
# # TODO: Plot 1 image from the training set. Set the title
# # of the plot to the corresponding class name.
# #
# for image, label in train_dataset.take(1):
#     image = image.numpy()
#     label = label.numpy()
#
#     label_str = str(label)
#     class_name = label_map[label_str]
#
#
#     plt.imshow(image)
#     plt.title(f"Class: {class_name}")
#     plt.axis('off')
#     plt.show()

# %% [markdown]
# ## Create Pipeline

# %%
# TODO: Create a pipeline for each set.

IMAGE_SIZE = 224  
BATCH_SIZE = 32    

def preprocess_img(image, label):
    image = tf.cast(image, tf.float32)
    image = tf.image.resize(image, [IMAGE_SIZE, IMAGE_SIZE]) 
    image = image / 255.0  
    return image, label

train_size = training_set.cardinality().numpy()
print(f"size of train: {train_size}")

train_data_processed = training_set.shuffle(buffer_size=train_size)
train_data_processed = train_data_processed.map(preprocess_img)
train_data_processed = train_data_processed.batch(BATCH_SIZE)
train_data_processed = train_data_processed.prefetch(tf.data.AUTOTUNE)

print("done ")
# Out:
# size of train: 1020
# done

# %%
validation_data_processed = validation_set.map(preprocess_img)
validation_data_processed = validation_data_processed.batch(BATCH_SIZE)
validation_data_processed = validation_data_processed.prefetch(tf.data.AUTOTUNE)

test_data_processed = test_set.map(preprocess_img)
test_data_processed = test_data_processed.batch(BATCH_SIZE)
test_data_processed = test_data_processed.prefetch(tf.data.AUTOTUNE)

print("done validation & test data ")
# Out:
# done validation & test data

# %% [markdown]
# # Build and Train the Classifier
#
# Now that the data is ready, it's time to build and train the classifier. You should use the MobileNet pre-trained model from TensorFlow Hub to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. If you want to talk through it with someone, chat with your fellow students!
#
# Refer to the rubric for guidance on successfully completing this section. Things you'll need to do:
#
# * Load the MobileNet pre-trained network from TensorFlow Hub.
# * Define a new, untrained feed-forward network as a classifier.
# * Train the classifier.
# * Plot the loss and accuracy values achieved during training for the training and validation set.
# * Save your trained model as a Keras model.
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right.
#
# **Note for Workspace users:** One important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module. Also, If your model is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %%
# !pip install --upgrade tensorflow tensorflow-hub
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.19.1)
# Collecting tensorflow
#   Using cached tensorflow-2.21.0-cp312-cp312-manylinux_2_27_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: tensorflow-hub in /usr/local/lib/python3.12/dist-packages (0.16.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (26.0)
# Collecting protobuf<8.0.0,>=6.31.1 (from tensorflow)
#   Using cached protobuf-7.34.1-cp310-abi3-manylinux2014_x86_64.whl.metadata (595 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.1.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.78.1)
# Requirement already satisfied: keras>=3.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: tf-keras>=2.14.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow-hub) (2.19.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.46.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.12.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.12.0->tensorflow) (0.19.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2026.1.4)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow-hub) (5.29.5)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.10.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.12.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.12.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow) (0.1.2)

# %%
import tensorflow as tf
import tensorflow_hub as hub

IMAGE_SIZE = 224

def create_model():
    module_url = 'https://tfhub.dev/google/imagenet/mobilenet_v3_large_075_224/feature_vector/5'
    
    def call_hub_layer(x):
        feature_layer = hub.KerasLayer(module_url, trainable=False)
        return feature_layer(x)
    
    nn_model = tf.keras.Sequential([
        tf.keras.layers.Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3)),
        tf.keras.layers.Lambda(call_hub_layer, name='mobilenet_features'),
        tf.keras.layers.Dense(1000, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(102, activation='softmax')
    ])
    
    return nn_model

nn_model = create_model()
nn_model.summary()
nn_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ mobilenet_features (Lambda)     │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1000)           │     1,281,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 1000)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 102)            │       102,102 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,383,102 (5.28 MB)
#  Trainable params: 1,383,102 (5.28 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
EPOCHS = 3
training_history = nn_model.fit(train_data_processed, epochs=EPOCHS, validation_data=validation_data_processed)
plt.figure(figsize=(12, 5))
# Out:
# Epoch 1/3
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.9922 - loss: 0.0124 - val_accuracy: 0.8235 - val_loss: 0.8302
# Epoch 2/3
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9951 - loss: 0.0153 - val_accuracy: 0.8500 - val_loss: 0.7351
# Epoch 3/3
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9971 - loss: 0.0107 - val_accuracy: 0.8529 - val_loss: 0.7017

# %%
# TODO: Plot the loss and accuracy values achieved during training for the training and validation set.

plt.figure(figsize=(12, 5))

# Training and validation accuracy plot
plt.subplot(1, 2, 1)
plt.plot(training_history.history['accuracy'], label='Training Accuracy')
plt.plot(training_history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# Drawing training loss and verification
plt.subplot(1, 2, 2)
plt.plot(training_history.history['loss'], label='Training Loss')
plt.plot(training_history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.show()

# %%
EPOCHS = 10
training_history = nn_model.fit(train_data_processed, epochs=EPOCHS, validation_data=validation_data_processed)
plt.figure(figsize=(12, 5))
# Out:
# Epoch 1/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.9716 - loss: 0.1421 - val_accuracy: 0.8382 - val_loss: 0.6311
# Epoch 2/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.9922 - loss: 0.0766 - val_accuracy: 0.8480 - val_loss: 0.5876
# Epoch 3/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9912 - loss: 0.0675 - val_accuracy: 0.8461 - val_loss: 0.6200
# Epoch 4/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9980 - loss: 0.0504 - val_accuracy: 0.8441 - val_loss: 0.5731
# Epoch 5/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9961 - loss: 0.0394 - val_accuracy: 0.8520 - val_loss: 0.5729
# Epoch 6/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9941 - loss: 0.0481 - val_accuracy: 0.8549 - val_loss: 0.5461
# Epoch 7/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9931 - loss: 0.0356 - val_accuracy: 0.8510 - val_loss: 0.5566
# Epoch 8/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9980 - loss: 0.0221 - val_accuracy: 0.8608 - val_loss: 0.5282
# Epoch 9/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - accuracy: 0.9980 - loss: 0.0239 - val_accuracy: 0.8461 - val_loss: 0.5655
# Epoch 10/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - accuracy: 0.9990 - loss: 0.0163 - val_accuracy: 0.8676 - val_loss: 0.5240

# %%
# TODO: Plot the loss and accuracy values achieved during training for the training and validation set.

plt.figure(figsize=(12, 5))

# Training and validation accuracy plot
plt.subplot(1, 2, 1)
plt.plot(training_history.history['accuracy'], label='Training Accuracy')
plt.plot(training_history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# Drawing training loss and verification
plt.subplot(1, 2, 2)
plt.plot(training_history.history['loss'], label='Training Loss')
plt.plot(training_history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.show()

# %%
EPOCHS = 50
training_history = nn_model.fit(train_data_processed, epochs=EPOCHS, validation_data=validation_data_processed)
plt.figure(figsize=(12, 5))
# Out:
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 1.0000 - loss: 0.0119 - val_accuracy: 0.8706 - val_loss: 0.5159
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 1.0000 - loss: 0.0108 - val_accuracy: 0.8637 - val_loss: 0.5270
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - accuracy: 1.0000 - loss: 0.0097 - val_accuracy: 0.8667 - val_loss: 0.5082
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9990 - loss: 0.0102 - val_accuracy: 0.8520 - val_loss: 0.5325
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 1.0000 - loss: 0.0092 - val_accuracy: 0.8608 - val_loss: 0.5241
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 0.8647 - val_loss: 0.5137
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 0.8716 - val_loss: 0.5102
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 0.8686 - val_loss: 0.5101
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 0.8647 - val_loss: 0.5088
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9990 - loss: 0.0077 - val_accuracy: 0.8618 - val_loss: 0.5235
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 1.0000 - loss: 0.0071 - val_accuracy: 0.8686 - val_loss: 0.5140
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 0.8676 - val_loss: 0.5162
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.8637 - val_loss: 0.5149
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.8676 - val_loss: 0.4968
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.8706 - val_loss: 0.5011
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.8696 - val_loss: 0.5153
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.8716 - val_loss: 0.5046
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.8735 - val_loss: 0.5057
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9990 - loss: 0.0051 - val_accuracy: 0.8618 - val_loss: 0.5254
# Epoch 20/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.8716 - val_loss: 0.5017
# Epoch 21/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 0.8676 - val_loss: 0.5266
# Epoch 22/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.8696 - val_loss: 0.5373
# Epoch 23/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.8706 - val_loss: 0.5130
# Epoch 24/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.8725 - val_loss: 0.5161
# Epoch 25/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.8745 - val_loss: 0.5100
# Epoch 26/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.8696 - val_loss: 0.5314
# Epoch 27/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.8706 - val_loss: 0.5276
# Epoch 28/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.8667 - val_loss: 0.5194
# Epoch 29/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.8725 - val_loss: 0.5144
# Epoch 30/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.8775 - val_loss: 0.5067
# Epoch 31/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.8804 - val_loss: 0.5077
# Epoch 32/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.8794 - val_loss: 0.5046
# Epoch 33/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.8716 - val_loss: 0.5094
# Epoch 34/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.8765 - val_loss: 0.5086
# Epoch 35/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.8814 - val_loss: 0.5065
# Epoch 36/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.8735 - val_loss: 0.5108
# Epoch 37/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.8765 - val_loss: 0.5121
# Epoch 38/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.8745 - val_loss: 0.5179
# Epoch 39/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.8775 - val_loss: 0.5144
# Epoch 40/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.8784 - val_loss: 0.5110
# Epoch 41/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 1.0000 - loss: 8.6830e-04 - val_accuracy: 0.8784 - val_loss: 0.5025
# Epoch 42/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.8745 - val_loss: 0.5018
# Epoch 43/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.8755 - val_loss: 0.5113
# Epoch 44/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.8755 - val_loss: 0.5068
# Epoch 45/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.8765 - val_loss: 0.5141
# Epoch 46/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.8775 - val_loss: 0.5089
# Epoch 47/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.8725 - val_loss: 0.5057
# Epoch 48/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 1.0000 - loss: 8.7235e-04 - val_accuracy: 0.8775 - val_loss: 0.5080
# Epoch 49/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 1.0000 - loss: 7.4648e-04 - val_accuracy: 0.8804 - val_loss: 0.5067
# Epoch 50/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 1.0000 - loss: 8.3712e-04 - val_accuracy: 0.8725 - val_loss: 0.5238

# %%
# TODO: Plot the loss and accuracy values achieved during training for the training and validation set.

plt.figure(figsize=(12, 5))

# Training and validation accuracy plot
plt.subplot(1, 2, 1)
plt.plot(training_history.history['accuracy'], label='Training Accuracy')
plt.plot(training_history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# Drawing training loss and verification
plt.subplot(1, 2, 2)
plt.plot(training_history.history['loss'], label='Training Loss')
plt.plot(training_history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.show()

# %%
EPOCHS = 7
training_history = nn_model.fit(train_data_processed, epochs=EPOCHS, validation_data=validation_data_processed)
plt.figure(figsize=(12, 5))
# Out:
# Epoch 1/7
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.8706 - val_loss: 0.5235
# Epoch 2/7
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.9990 - loss: 0.0016 - val_accuracy: 0.8686 - val_loss: 0.5315
# Epoch 3/7
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.8706 - val_loss: 0.5322
# Epoch 4/7
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9980 - loss: 0.0037 - val_accuracy: 0.8627 - val_loss: 0.5679
# Epoch 5/7
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.8706 - val_loss: 0.5321
# Epoch 6/7
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9971 - loss: 0.0076 - val_accuracy: 0.8500 - val_loss: 0.6028
# Epoch 7/7
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9882 - loss: 0.0483 - val_accuracy: 0.8216 - val_loss: 0.7045

# %%
# TODO: Plot the loss and accuracy values achieved during training for the training and validation set.

plt.figure(figsize=(12, 5))

# Training and validation accuracy plot
plt.subplot(1, 2, 1)
plt.plot(training_history.history['accuracy'], label='Training Accuracy')
plt.plot(training_history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# Drawing training loss and verification
plt.subplot(1, 2, 2)
plt.plot(training_history.history['loss'], label='Training Loss')
plt.plot(training_history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.show()

# %%
EPOCHS = 6
training_history = nn_model.fit(train_data_processed, epochs=EPOCHS, validation_data=validation_data_processed)
plt.figure(figsize=(12, 5))
# Out:
# Epoch 1/6
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9245 - loss: 0.2386 - val_accuracy: 0.7755 - val_loss: 1.0031
# Epoch 2/6
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9461 - loss: 0.1352 - val_accuracy: 0.8108 - val_loss: 0.9457
# Epoch 3/6
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.9784 - loss: 0.0667 - val_accuracy: 0.8157 - val_loss: 0.8067
# Epoch 4/6
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9833 - loss: 0.0466 - val_accuracy: 0.8373 - val_loss: 0.7647
# Epoch 5/6
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9843 - loss: 0.0404 - val_accuracy: 0.8265 - val_loss: 0.7934
# Epoch 6/6
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9912 - loss: 0.0324 - val_accuracy: 0.8127 - val_loss: 0.8361

# %%
# TODO: Plot the loss and accuracy values achieved during training for the training and validation set.

plt.figure(figsize=(12, 5))

# Training and validation accuracy plot
plt.subplot(1, 2, 1)
plt.plot(training_history.history['accuracy'], label='Training Accuracy')
plt.plot(training_history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# Drawing training loss and verification
plt.subplot(1, 2, 2)
plt.plot(training_history.history['loss'], label='Training Loss')
plt.plot(training_history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.show()

# %%
EPOCHS = 5
training_history = nn_model.fit(train_data_processed, epochs=EPOCHS, validation_data=validation_data_processed)
plt.figure(figsize=(12, 5))
# Out:
# Epoch 1/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 36s 515ms/step - accuracy: 0.2029 - loss: 3.8214 - val_accuracy: 0.6647 - val_loss: 2.1732
# Epoch 2/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.6941 - loss: 1.3639 - val_accuracy: 0.7480 - val_loss: 1.1020
# Epoch 3/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.8667 - loss: 0.6075 - val_accuracy: 0.8324 - val_loss: 0.7841
# Epoch 4/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.9324 - loss: 0.3304 - val_accuracy: 0.8294 - val_loss: 0.6811
# Epoch 5/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.9549 - loss: 0.1967 - val_accuracy: 0.8382 - val_loss: 0.6323

# %%
# TODO: Plot the loss and accuracy values achieved during training for the training and validation set.

plt.figure(figsize=(12, 5))

# Training and validation accuracy plot
plt.subplot(1, 2, 1)
plt.plot(training_history.history['accuracy'], label='Training Accuracy')
plt.plot(training_history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# Drawing training loss and verification
plt.subplot(1, 2, 2)
plt.plot(training_history.history['loss'], label='Training Loss')
plt.plot(training_history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.show()

# %% [markdown]
# ## Testing your Network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# TODO: Print the loss and accuracy values achieved on the entire test set.

test_loss, test_accuracy = nn_model.evaluate(test_data_processed)
print("Test Loss: {:.4f}".format(test_loss))
print("Test Accuracy: {:.4f}".format(test_accuracy))
# Out:
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 9s 48ms/step - accuracy: 0.8224 - loss: 0.7035
# Test Loss: 0.7035
# Test Accuracy: 0.8224

# %% [markdown]
# ## Save the Model
#
# Now that your network is trained, save the model so you can load it later for making inference. In the cell below save your model as a Keras model (*i.e.* save it as an HDF5 file).

# %%
# TODO: Save your trained model as a Keras model.

time = time.time()
model_file_name = f'./{int(time)}.h5'
nn_model.save(model_file_name)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## Load the Keras Model
#
# Load the Keras model you saved above.

# %%
import tensorflow as tf
import tensorflow_hub as hub

def call_hub_layer(x):
    module_url = 'https://tfhub.dev/google/imagenet/mobilenet_v3_large_075_224/feature_vector/5'
    feature_layer = hub.KerasLayer(module_url, trainable=False)
    return feature_layer(x)

# %%
# TODO: Load the Keras model
with tf.keras.utils.custom_object_scope({'call_hub_layer': call_hub_layer}):
    restored_model = tf.keras.models.load_model(model_file_name)
print("Model loaded successfully!")
print(restored_model.summary())
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model loaded successfully!
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ mobilenet_features (Lambda)     │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1000)           │     1,281,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 1000)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 102)            │       102,102 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,383,104 (5.28 MB)
#  Trainable params: 1,383,102 (5.28 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)
# None

# %% [markdown]
# # Inference for Classification
#
# Now you'll write a function that uses your trained network for inference. Write a function called `predict` that takes an image, a model, and then returns the top $K$ most likely class labels along with the probabilities. The function call should look like:
#
# ```python
# probs, classes = predict(image_path, model, top_k)
# ```
#
# If `top_k=5` the output of the `predict` function should be something like this:
#
# ```python
# probs, classes = predict(image_path, model, 5)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# Your `predict` function should use `PIL` to load the image from the given `image_path`. You can use the [Image.open](https://pillow.readthedocs.io/en/latest/reference/Image.html#PIL.Image.open) function to load the images. The `Image.open()` function returns an `Image` object. You can convert this `Image` object to a NumPy array by using the `np.asarray()` function.
#
# The `predict` function will also need to handle pre-processing the input image such that it can be used by your model. We recommend you write a separate function called `process_image` that performs the pre-processing. You can then call the `process_image` function from the `predict` function.
#
# ### Image Pre-processing
#
# The `process_image` function should take in an image (in the form of a NumPy array) and return an image in the form of a NumPy array with shape `(224, 224, 3)`.
#
# First, you should convert your image into a TensorFlow Tensor and then resize it to the appropriate size using `tf.image.resize`.
#
# Second, the pixel values of the input images are typically encoded as integers in the range 0-255, but the model expects the pixel values to be floats in the range 0-1. Therefore, you'll also need to normalize the pixel values.
#
# Finally, convert your image back to a NumPy array using the `.numpy()` method.

# %%
# TODO: Create the process_image function

def process_img(image):
    img = tf.convert_to_tensor(image, dtype=tf.float32)
    img = tf.image.resize(img, (224, 224))
    img /= 255.0  
    return img.numpy()

# %% [markdown]
# To check your `process_image` function we have provided 4 images in the `./test_images/` folder:
#
# * cautleya_spicata.jpg
# * hard-leaved_pocket_orchid.jpg
# * orange_dahlia.jpg
# * wild_pansy.jpg
#
# The code below loads one of the above images using `PIL` and plots the original image alongside the image produced by your `process_image` function. If your `process_image` function works, the plotted image should be the correct size.

# %%
image_path = '/kaggle/input/datasets/leyanbuirat/test-image/wild_pansy.jpg'
image_object = Image.open(image_path)
original_image = np.asarray(image_object)
processed_image = process_img(original_image)

fig, (ax1, ax2) = plt.subplots(figsize=(10, 10), ncols=2)
ax1.imshow(original_image)
ax1.set_title('Original Image')
ax2.imshow(processed_image)
ax2.set_title('Processed Image')

plt.tight_layout()
plt.show()

# %% [markdown]
# Once you can get images in the correct format, it's time to write the `predict` function for making inference with your model.
#
# ### Inference
#
# Remember, the `predict` function should take an image, a model, and then returns the top $K$ most likely class labels along with the probabilities. The function call should look like:
#
# ```python
# probs, classes = predict(image_path, model, top_k)
# ```
#
# If `top_k=5` the output of the `predict` function should be something like this:
#
# ```python
# probs, classes = predict(image_path, model, 5)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# Your `predict` function should use `PIL` to load the image from the given `image_path`. You can use the [Image.open](https://pillow.readthedocs.io/en/latest/reference/Image.html#PIL.Image.open) function to load the images. The `Image.open()` function returns an `Image` object. You can convert this `Image` object to a NumPy array by using the `np.asarray()` function.
#
# **Note:** The image returned by the `process_image` function is a NumPy array with shape `(224, 224, 3)` but the model expects the input images to be of shape `(1, 224, 224, 3)`. This extra dimension represents the batch size. We suggest you use the `np.expand_dims()` function to add the extra dimension.

# %%
# TODO: Create the predict function

def preprocess_img(image_path):
    image = Image.open(image_path).convert('RGB')
    image_array = np.asarray(image)
    image_tensor = tf.convert_to_tensor(image_array, dtype=tf.float32)
    image_resized = tf.image.resize(image_tensor, (224, 224))
    image_normalized = image_resized / 255.0
    image_expanded = np.expand_dims(image_normalized, axis=0)
    return image_expanded

def predict_top_k(image_path, nn_model, top_k=5):
    processed_img = preprocess_img(image_path)
    predictions = nn_model.predict(processed_img)
    top_k_values, top_k_indices = tf.math.top_k(predictions[0], k=top_k)
    top_k_values = top_k_values.numpy()
    top_k_indices = top_k_indices.numpy()
    top_k_classes = [str(index) for index in top_k_indices]
    return top_k_values, top_k_classes

image_path = '/kaggle/input/datasets/leyanbuirat/test-image/wild_pansy.jpg'
top_k = 5
probabilities, predicted_classes = predict_top_k(image_path, nn_model, top_k)

print("Probabilities:", probabilities)
print("Classes:", predicted_classes)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step
# Probabilities: [9.9890149e-01 4.4401988e-04 1.1421768e-04 8.1886945e-05 5.2599265e-05]
# Classes: ['51', '18', '81', '75', '0']

# %% [markdown]
# # Sanity Check
#
# It's always good to check the predictions made by your model to make sure they are correct. To check your predictions we have provided 4 images in the `./test_images/` folder:
#
# * cautleya_spicata.jpg
# * hard-leaved_pocket_orchid.jpg
# * orange_dahlia.jpg
# * wild_pansy.jpg
#
# In the cell below use `matplotlib` to plot the input image alongside the probabilities for the top 5 classes predicted by your model. Plot the probabilities as a bar graph. The plot should look like this:
#
# <img src='assets/inference_example.png' width=600px>
#
# You can convert from the class integer labels to actual flower names using `class_names`.

# %%
# TODO: Plot the input image along with the top 5 classes

def preprocess_img(image_path):
    image = Image.open(image_path).convert('RGB')
    image_array = np.asarray(image)
    image_tensor = tf.convert_to_tensor(image_array, dtype=tf.float32)
    image_resized = tf.image.resize(image_tensor, (224, 224))
    image_normalized = image_resized / 255.0
    image_expanded = np.expand_dims(image_normalized, axis=0)
    return image_expanded

def predict_top_k(image_path, nn_model, top_k=5):
    processed_image = preprocess_img(image_path)
    predictions = nn_model.predict(processed_image)
    top_k_probs, top_k_classes = tf.math.top_k(predictions, k=top_k)
    top_k_probs = top_k_probs.numpy().flatten()
    top_k_classes = top_k_classes.numpy().flatten()   
    return top_k_probs, top_k_classes

image_path = '/kaggle/input/datasets/leyanbuirat/test-image/hard-leaved_pocket_orchid.jpg'
true_label = os.path.splitext(os.path.basename(image_path))[0]
top_k = 5
probabilities, predicted_classes = predict_top_k(image_path, nn_model, top_k=top_k)
    
image_object = Image.open(image_path)
image_object = image_object.resize((IMAGE_SIZE, IMAGE_SIZE))  
image_array = np.array(image_object) / 255.0  
image_array = np.expand_dims(image_array, axis=0)  
    
predictions = nn_model.predict(image_array)[0]
top_k_labels = [class_names[str(i)] for i in predicted_classes]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
ax1.imshow(image_object)
ax1.axis("off") 
ax1.set_title(true_label)
ax2.barh(top_k_labels, probabilities)
ax2.set_xlabel("Probability")
ax2.set_title("Top 5 Predictions")
ax2.invert_yaxis()  
plt.tight_layout()
plt.show()

print(class_names[str(1)])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# hard-leaved pocket orchid

# %%
print(class_names[str(1)])
# Out:
# hard-leaved pocket orchid
